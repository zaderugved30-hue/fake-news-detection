# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

model_path = "./local_fake_news_model"   

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

def detect_fake(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    outputs = model(**inputs)
    pred = torch.argmax(outputs.logits).item()
    return "Fake News" if pred == 0 else "Real News"

print(detect_fake("This is some sample news text here..."))
# Out:
# Fake News

# %%
detect_fake("Government providing free cars to all students.")
# Out:
# 'Real News'

# %%
import os

from pydantic import BaseModel, Field
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser


# ✅ Structured output model
class FakeNewsOutput(BaseModel):
    fake: bool = Field(description="True if the news appears to be fake, otherwise False.")
    reasoning: str = Field(description="Short explanation of why it is considered fake or real.")

# ✅ Model + parser setup
parser = PydanticOutputParser(pydantic_object=FakeNewsOutput)
model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-exp",
    api_key="AIzaSyDP4rGLovprRGY_AuAV1EZiM25Y72DCMD0"
)

def detect_fake_news(news_text):
    prompt = ChatPromptTemplate.from_template("""
    You are a fake news classification expert.
    Analyze the following news and determine whether it is fake or real.

    News:
    {news_text}

    {format_instructions}
    """)

    formatted_prompt = prompt.format_messages(
        news_text=news_text,
        format_instructions=parser.get_format_instructions()
    )

    response = model.invoke(formatted_prompt)
    parsed_output = parser.parse(response.content)

    return parsed_output.fake, parsed_output.reasoning


# ✅ Test
news_text = "Government will deposit ₹10 lakh in every citizen's bank account from next month."
result = detect_fake_news(news_text)
print(result)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# (True, "It is highly improbable that the government would deposit such a large sum of money into every citizen's account. This claim lacks credibility and is likely fabricated.")

# %%
import os

from pydantic import BaseModel, Field
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser


# ✅ Structured output model
class FakeNewsOutput(BaseModel):
    fake: bool = Field(description="True if the news appears to be fake, otherwise False.")
    reasoning: str = Field(description="Short explanation of why it is considered fake or real.")

# ✅ Model + parser setup
parser = PydanticOutputParser(pydantic_object=FakeNewsOutput)
model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-exp",
    api_key="AIzaSyDP4rGLovprRGY_AuAV1EZiM25Y72DCMD0"
)

def detect_fake_news(news_text):
    prompt = ChatPromptTemplate.from_template("""
    You are a fake news classification expert.
    Analyze the following news and determine whether it is fake or real.

    News:
    {news_text}

    {format_instructions}
    """)

    formatted_prompt = prompt.format_messages(
        news_text=news_text,
        format_instructions=parser.get_format_instructions()
    )

    response = model.invoke(formatted_prompt)
    parsed_output = parser.parse(response.content)

    return parsed_output.fake, parsed_output.reasoning


# ✅ Test
news_text = "Government will deposit ₹10 lakh in every citizen's bank account from next month."
result = detect_fake_news(news_text)
print(result)
# Out:
# (True, "It is highly improbable that the government would deposit such a large amount of money into every citizen's account. This would likely cause hyperinflation and destabilize the economy. There is no credible source reporting this news.")

# %%
import os
from pydantic import BaseModel, Field
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser


# ✅ Structured output model
class FakeNewsOutput(BaseModel):
    fake: bool = Field(description="True if the news appears to be fake, otherwise False.")

# ✅ Model + parser setup
parser = PydanticOutputParser(pydantic_object=FakeNewsOutput)
model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-exp",
    api_key="AIzaSyDP4rGLovprRGY_AuAV1EZiM25Y72DCMD0" 
)

def detect_fake_news(news_text):
    prompt = ChatPromptTemplate.from_template("""
    You are an expert in fake news classification.
    Respond only with TRUE or FALSE, indicating if the news is fake.

    News:
    {news_text}

    {format_instructions}
    """)

    formatted_prompt = prompt.format_messages(
        news_text=news_text,
        format_instructions=parser.get_format_instructions()
    )

    response = model.invoke(formatted_prompt)
    parsed_output = parser.parse(response.content)

    return parsed_output.fake  # ✅ returns only True/False


# ✅ Test
news_text = "Government will deposit ₹10 lakh in every citizen's bank account from next month."
print(detect_fake_news(news_text))
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details..
# True

# %%
# Out:
# Package                 Version
# ----------------------- -----------
# aiohappyeyeballs        2.6.1
# aiohttp                 3.13.2
# aiosignal               1.4.0
# annotated-types         0.7.0
# anyio                   4.11.0
# asttokens               3.0.0
# attrs                   25.4.0
# certifi                 2025.10.5
# charset-normalizer      3.4.4
# colorama                0.4.6
# comm                    0.2.3
# datasets                4.4.1
# debugpy                 1.8.17
# decorator               5.2.1
# dill                    0.4.0
# executing               2.2.1
# filelock                3.20.0
# frozenlist              1.8.0
# fsspec                  2025.10.0
# h11                     0.16.0
# hf-xet                  1.2.0
# httpcore                1.0.9
# httpx                   0.28.1
# huggingface-hub         0.36.0
# idna                    3.11
# ipykernel               7.1.0
# ipython                 9.7.0
# ipython_pygments_lexers 1.1.1
# ...
